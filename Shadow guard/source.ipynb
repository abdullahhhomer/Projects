# %%
import numpy as np
import multiprocessing as mp
import pandas as pd
import csv
from collections import defaultdict, deque
from tensorflow.keras.models import load_model
from sklearn.preprocessing import MinMaxScaler
import random

# %%
class Node:
    def __init__(self, **kwargs):
        self.device_ip = kwargs["device_ip"]
        self.port_number = kwargs["port_number"]
        self.protocol_used = kwargs["protocol_used"]
        self.packets_received = int(kwargs["packets_received"]) if kwargs["packets_received"].isdigit() else 0
        self.packets_forwarded = int(kwargs["packets_forwarded"]) if kwargs["packets_forwarded"].isdigit() else 0
        self.unusual_login_attempts = int(kwargs["unusual_login_attempts"]) if kwargs["unusual_login_attempts"].isdigit() else 0
        self.resources_shared = kwargs["resources_shared"]
        self.device_type = kwargs["device_type"]
        self.cpu_usage = kwargs["cpu_usage"]
        self.memory_usage = kwargs["memory_usage"]
        self.storage_usage = kwargs["storage_usage"]
        self.device_uptime = kwargs["device_uptime"]
        self.os_version = kwargs["os_version"]
        self.connection_status = kwargs["connection_status"]
        self.latency = kwargs["latency"]
        self.error_rate = kwargs["error_rate"]
        self.bandwidth_usage = kwargs["bandwidth_usage"]
        self.data_transferred = int(kwargs["data_transferred"]) if kwargs["data_transferred"].isdigit() else 0
        self.security_level = kwargs["security_level"]
        self.vpn_status = kwargs["vpn_status"]
        self.firmware_version = kwargs["firmware_version"]
        self.last_maintenance_date = kwargs["last_maintenance_date"]
        self.label = kwargs["label"]
        self.attack_type = kwargs["attack_type"]

# %%
def read_and_segment_csv_to_nodes(file_path):
    
    server_networks = defaultdict(list)

    
    node_objects = []

    
    with open(file_path, 'r') as file:
        reader = csv.DictReader(file)
        rows = list(reader)

    
    servers = set()
    for row in rows:
        node = Node(
            device_ip=row["device_ip"],
            port_number=row["port_number"],
            protocol_used=row["protocol_used"],
            packets_received=row["packets_received"],
            packets_forwarded=row["packets_forwarded"],
            unusual_login_attempts=row["unusual_login_attempts"],
            resources_shared=row["resources_shared"],
            device_type=row["device_type"],
            cpu_usage=row["cpu_usage"],
            memory_usage=row["memory_usage"],
            storage_usage=row["storage_usage"],
            device_uptime=row["device_uptime"],
            os_version=row["os_version"],
            connection_status=row["connection_status"],
            latency=row["latency"],
            error_rate=row["error_rate"],
            bandwidth_usage=row["bandwidth_usage"],
            data_transferred=row["data_transferred"],
            security_level=row["security_level"],
            vpn_status=row["vpn_status"],
            firmware_version=row["firmware_version"],
            last_maintenance_date=row["last_maintenance_date"],
            label=row["label"],
            attack_type=row["attack_type"]
        )
        node_objects.append(node)

        
        ip_parts = row['device_ip'].split('.')
        if ip_parts[-1] == '0':  
            servers.add('.'.join(ip_parts[:3]))
    for node in node_objects:
        ip_prefix = '.'.join(node.device_ip.split('.')[:3])
        if ip_prefix in servers:
            server_networks[ip_prefix].append(node)

    return server_networks, node_objects

# %%
def create_graph(server_networks):
    graphs = {}
    for server, nodes in server_networks.items():
        graph = defaultdict(list)
        for node in nodes:
            graph[node.device_ip]  
            for other in nodes:
                if node.device_ip != other.device_ip:
                    graph[node.device_ip].append(other.device_ip)
        graphs[server] = graph
    return graphs

# %% [markdown]
# # Evaluate

# %%
def evaluate_attack_conditions(node):
    if node.packets_received > 6000 or node.packets_forwarded > 3000:        
        return True
    elif node.unusual_login_attempts > 4:
        return True
    elif node.data_transferred > 5000:
        return True
    else:
        return False

# %% [markdown]
# # BFS

# %%
def bfs_search(graph, server_nodes):
    suspected_queue = deque()
    seen = set()  # Set to track unique nodes in the queue

    for start_node in server_nodes:
        visited = set()
        queue = deque([start_node.device_ip])

        while queue:
            current_ip = queue.popleft()
            if current_ip in visited:
                continue
            visited.add(current_ip)

            # Fetch node from its IP
            current_node = next(node for node in server_nodes if node.device_ip == current_ip)

            # Evaluate attack conditions
            if evaluate_attack_conditions(current_node) and current_node.device_ip not in seen:
                suspected_queue.append(current_node)
                seen.add(current_node.device_ip)  # Mark as seen

            # Enqueue neighbors
            for neighbor in graph[current_ip]:
                if neighbor not in visited:
                    queue.append(neighbor)

    return suspected_queue

# %% [markdown]
# # Data For Model

# %%
# device_ip
# port_number
# protocol_used
# packets_received
# packets_forwarded
# unusual_login_attempts
# resources_shared
# device_type
# cpu_usage
# memory_usage
# storage_usage
# device_uptime
# os_version
# connection_status
# latency
# error_rate
# bandwidth_usage
# data_transferred
# security_level
# vpn_status
# firmware_version
# last_maintenance_date
# label
# attack_type


model = load_model('trained_model.keras')

def predict(sus):
    
    malicious = []
    x1 = []
    x2 = []
    x3 = []
    x4 = []
    x5 = []
    x6 = []
    x7 = []
    x8 = []
    x9 = []
    x10 = []
    x11 = []

    for i in range (len(sus)):
        x1.append(sus[i].packets_received)
        x2.append(sus[i].packets_forwarded)
        x3.append(sus[i].unusual_login_attempts)
        x4.append(sus[i].resources_shared)
        x5.append(sus[i].cpu_usage)
        x6.append(sus[i].memory_usage)
        x7.append(sus[i].storage_usage)
        x8.append(sus[i].device_uptime)
        x9.append(sus[i].latency)
        x10.append(sus[i].bandwidth_usage)
        x11.append(sus[i].data_transferred)
    
    x1 = np.array(x1)
    x2 = np.array(x2)
    x3 = np.array(x3)
    x4 = np.array(x4)
    x5 = np.array(x5)
    x6 = np.array(x6)
    x7 = np.array(x7)
    x8 = np.array(x8)
    x9 = np.array(x9)
    x10 = np.array(x10)
    x11 = np.array(x11)

    print(x1.shape)
    print(x2.shape)
    print(x3.shape)
    print(x4.shape)
    print(x5.shape)
    print(x6.shape)
    print(x7.shape)
    print(x8.shape)
    print(x9.shape)
    print(x10.shape)
    print(x11.shape)

    x1 = x1.astype(float)
    x2 = x2.astype(float)
    x3 = x3.astype(float)
    x4 = x4.astype(float)
    x5 = x5.astype(float)
    x6 = x6.astype(float)
    x7 = x7.astype(float)
    x8 = x8.astype(float)
    x9 = x9.astype(float)
    x10 = x10.astype(float)
    x11 = x11.astype(float)


    print(x1.dtype)
    print(x2.dtype)
    print(x3.dtype)
    print(x4.dtype)
    print(x5.dtype)
    print(x6.dtype)
    print(x7.dtype)
    print(x8.dtype)
    print(x9.dtype)
    print(x10.dtype)
    print(x11.dtype)

    x = np.array([x8, x9, x10, x1, x2, x11, x4, x5, x6, x7, x3])
    x = np.hstack([arr.reshape(-1, 1) for arr in x])
    
    print(x.dtype)
    
    y = model.predict(x)

    for i in range (len(sus)):
        if(y[i] > 0.5):
            malicious.append(sus[i].device_ip)
    

    return malicious

# %% [markdown]
# # Remove Node

# %%
def remove_malicious_nodes_bfs(graphs, sus_ips):
    for subnet, graph in graphs.items():
        visited = set()

        for ip in sus_ips:
            if ip in visited or ip not in graph:
                continue

            # Perform BFS from this malicious node
            queue = deque([ip])
            while queue:
                current_ip = queue.popleft()
                if current_ip in visited:
                    continue
                visited.add(current_ip)

                # Remove the node from its neighbors
                if current_ip in graph:
                    neighbors = graph[current_ip].copy()  # Copy to avoid modifying while iterating
                    for neighbor in neighbors:
                        if current_ip in graph.get(neighbor, []):
                            graph[neighbor].remove(current_ip)

                    # Remove the current node itself
                    del graph[current_ip]
                    print(f"Node {current_ip} removed from subnet {subnet}!")

                # Add neighbors of this node to the queue for further traversal
                for neighbor in neighbors:
                    if neighbor not in visited:
                        queue.append(neighbor)

# %% [markdown]
# # Main

# %%
def main():
    file_path = "data2.csv"
    server_networks, all_nodes = read_and_segment_csv_to_nodes(file_path)

    # Convert networks to graphs
    graphs = create_graph(server_networks)

    # BFS and attack evaluation
    suspected_attacks = deque()
    seen_nodes = set()  # To ensure unique nodes across all server networks

    for server, nodes in server_networks.items():
        unique_attacks = bfs_search(graphs[server], nodes)
        for attack in unique_attacks:
            if attack.device_ip not in seen_nodes:
                suspected_attacks.append(attack)
                seen_nodes.add(attack.device_ip)

    # Display suspected attacks
    # print("Suspected Attack Nodes:")
    # for node in suspected_attacks:
    #     print(f"Device IP: {node.device_ip}, Attack Type: {node.attack_type}")
    
    
    # bhai ye sus attacks par prediction wala model laga kar aik array return kar raha hoon
    # array mae jo bhi howa wo graph sae khatam kar doon ga
    print (len(suspected_attacks))
    malicious = predict(suspected_attacks)    
    remove_malicious_nodes_bfs(graphs, malicious)



if __name__ == "__main__":
    main()
# Out:
# 503
# (503,)
# (503,)
# (503,)
# (503,)
# (503,)
# (503,)
# (503,)
# (503,)
# (503,)
# (503,)
# (503,)
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Node 192.168.1.173 removed from subnet 192.168.1!
# Node 192.168.1.56 removed from subnet 192.168.1!
# Node 192.168.1.142 removed from subnet 192.168.1!
# Node 192.168.1.0 removed from subnet 192.168.1!
# Node 192.168.1.193 removed from subnet 192.168.1!
# Node 192.168.1.37 removed from subnet 192.168.1!
# Node 192.168.1.130 removed from subnet 192.168.1!
# Node 192.168.1.85 removed from subnet 192.168.1!
# Node 192.168.1.238 removed from subnet 192.168.1!
# Node 192.168.1.224 removed from subnet 192.168.1!
# Node 192.168.1.29 removed from subnet 192.168.1!
# Node 192.168.1.167 removed from subnet 192.168.1!
# Node 192.168.1.2 removed from subnet 192.168.1!
# Node 192.168.1.50 removed from subnet 192.168.1!
# Node 192.168.1.87 removed from subnet 192.168.1!
# Node 192.168.1.111 removed from subnet 192.168.1!
# Node 192.168.1.151 removed from subnet 192.168.1!
# Node 192.168.1.127 removed from subnet 192.168.1!
# Node 192.168.1.105 removed from subnet 192.168.1!
# Node 192.168.1.239 removed from subnet 192.168.1!
# Node 192.168.1.250 removed from subnet 192.168.1!
# Node 192.168.1.24 removed from subnet 192.168.1!
# Node 192.168.1.174 removed from subnet 192.168.1!
# Node 192.168.1.39 removed from subnet 192.168.1!
# Node 192.168.1.45 removed from subnet 192.168.1!
# Node 192.168.1.120 removed from subnet 192.168.1!
# Node 192.168.1.179 removed from subnet 192.168.1!
# Node 192.168.1.125 removed from subnet 192.168.1!
# Node 192.168.1.88 removed from subnet 192.168.1!
# Node 192.168.1.141 removed from subnet 192.168.1!
# Node 192.168.1.112 removed from subnet 192.168.1!
# Node 192.168.1.1 removed from subnet 192.168.1!
# Node 192.168.1.61 removed from subnet 192.168.1!
# Node 192.168.1.51 removed from subnet 192.168.1!
# Node 192.168.1.191 removed from subnet 192.168.1!
# Node 192.168.1.147 removed from subnet 192.168.1!
# Node 192.168.1.146 removed from subnet 192.168.1!
# Node 192.168.1.86 removed from subnet 192.168.1!
# Node 192.168.1.204 removed from subnet 192.168.1!
# Node 192.168.1.118 removed from subnet 192.168.1!
# Node 192.168.1.209 removed from subnet 192.168.1!
# Node 192.168.1.26 removed from subnet 192.168.1!
# Node 192.168.1.138 removed from subnet 192.168.1!
# Node 192.168.1.231 removed from subnet 192.168.1!
# Node 192.168.1.233 removed from subnet 192.168.1!
# Node 192.168.1.100 removed from subnet 192.168.1!
# Node 192.168.1.30 removed from subnet 192.168.1!
# Node 192.168.1.82 removed from subnet 192.168.1!
# Node 192.168.1.201 removed from subnet 192.168.1!
# Node 192.168.1.210 removed from subnet 192.168.1!
# Node 192.168.1.192 removed from subnet 192.168.1!
# Node 192.168.1.40 removed from subnet 192.168.1!
# Node 192.168.1.212 removed from subnet 192.168.1!
# Node 192.168.1.25 removed from subnet 192.168.1!
# Node 192.168.1.117 removed from subnet 192.168.1!
# Node 192.168.1.43 removed from subnet 192.168.1!
# Node 192.168.1.170 removed from subnet 192.168.1!
# Node 192.168.1.131 removed from subnet 192.168.1!
# Node 192.168.1.92 removed from subnet 192.168.1!
# Node 192.168.1.121 removed from subnet 192.168.1!
# Node 192.168.1.139 removed from subnet 192.168.1!
# Node 192.168.1.11 removed from subnet 192.168.1!
# Node 192.168.1.75 removed from subnet 192.168.1!
# Node 192.168.1.93 removed from subnet 192.168.1!
# Node 192.168.1.149 removed from subnet 192.168.1!
# Node 192.168.1.154 removed from subnet 192.168.1!
# Node 192.168.1.96 removed from subnet 192.168.1!
# Node 192.168.1.36 removed from subnet 192.168.1!
# Node 192.168.1.27 removed from subnet 192.168.1!
# Node 192.168.1.20 removed from subnet 192.168.1!
# Node 192.168.1.35 removed from subnet 192.168.1!
# Node 192.168.1.190 removed from subnet 192.168.1!
# Node 192.168.1.62 removed from subnet 192.168.1!
# Node 192.168.1.168 removed from subnet 192.168.1!
# Node 192.168.1.32 removed from subnet 192.168.1!
# Node 192.168.1.71 removed from subnet 192.168.1!
# Node 192.168.1.116 removed from subnet 192.168.1!
# Node 192.168.1.225 removed from subnet 192.168.1!
# Node 192.168.1.102 removed from subnet 192.168.1!
# Node 192.168.1.10 removed from subnet 192.168.1!
# Node 192.168.1.176 removed from subnet 192.168.1!
# Node 192.168.1.144 removed from subnet 192.168.1!
# Node 192.168.1.81 removed from subnet 192.168.1!
# Node 192.168.1.229 removed from subnet 192.168.1!
# Node 192.168.1.21 removed from subnet 192.168.1!
# Node 192.168.1.157 removed from subnet 192.168.1!
# Node 192.168.1.64 removed from subnet 192.168.1!
# Node 192.168.1.202 removed from subnet 192.168.1!
# Node 192.168.1.184 removed from subnet 192.168.1!
# Node 192.168.1.243 removed from subnet 192.168.1!
# Node 192.168.1.211 removed from subnet 192.168.1!
# Node 192.168.1.124 removed from subnet 192.168.1!
# Node 192.168.1.150 removed from subnet 192.168.1!
# Node 192.168.1.249 removed from subnet 192.168.1!
# Node 192.168.1.6 removed from subnet 192.168.1!
# Node 192.168.1.169 removed from subnet 192.168.1!
# Node 192.168.1.49 removed from subnet 192.168.1!
# Node 192.168.1.5 removed from subnet 192.168.1!
# Node 192.168.1.58 removed from subnet 192.168.1!
# Node 192.168.1.246 removed from subnet 192.168.1!
# Node 192.168.1.14 removed from subnet 192.168.1!
# Node 192.168.1.108 removed from subnet 192.168.1!
# Node 192.168.1.234 removed from subnet 192.168.1!
# Node 192.168.1.113 removed from subnet 192.168.1!
# Node 192.168.1.175 removed from subnet 192.168.1!
# Node 192.168.1.7 removed from subnet 192.168.1!
# Node 192.168.1.220 removed from subnet 192.168.1!
# Node 192.168.1.247 removed from subnet 192.168.1!
# Node 192.168.1.15 removed from subnet 192.168.1!
# Node 192.168.1.69 removed from subnet 192.168.1!
# Node 192.168.1.245 removed from subnet 192.168.1!
# Node 192.168.1.17 removed from subnet 192.168.1!
# Node 192.168.1.182 removed from subnet 192.168.1!
# Node 192.168.1.42 removed from subnet 192.168.1!
# Node 192.168.1.44 removed from subnet 192.168.1!
# Node 192.168.1.207 removed from subnet 192.168.1!
# Node 192.168.1.166 removed from subnet 192.168.1!
# Node 192.168.1.222 removed from subnet 192.168.1!
# Node 192.168.1.63 removed from subnet 192.168.1!
# Node 192.168.1.161 removed from subnet 192.168.1!
# Node 192.168.1.214 removed from subnet 192.168.1!
# Node 192.168.1.244 removed from subnet 192.168.1!
# Node 192.168.1.97 removed from subnet 192.168.1!
# Node 192.168.1.213 removed from subnet 192.168.1!
# Node 192.168.1.53 removed from subnet 192.168.1!
# Node 192.168.1.134 removed from subnet 192.168.1!
# Node 192.168.1.241 removed from subnet 192.168.1!
# Node 192.168.1.160 removed from subnet 192.168.1!
# Node 192.168.1.46 removed from subnet 192.168.1!
# Node 192.168.1.177 removed from subnet 192.168.1!
# Node 192.168.1.198 removed from subnet 192.168.1!
# Node 192.168.1.158 removed from subnet 192.168.1!
# Node 192.168.1.23 removed from subnet 192.168.1!
# Node 192.168.1.237 removed from subnet 192.168.1!
# Node 192.168.1.228 removed from subnet 192.168.1!
# Node 192.168.1.115 removed from subnet 192.168.1!
# Node 192.168.1.196 removed from subnet 192.168.1!
# Node 192.168.1.232 removed from subnet 192.168.1!
# Node 192.168.1.172 removed from subnet 192.168.1!
# Node 192.168.1.223 removed from subnet 192.168.1!
# Node 192.168.1.55 removed from subnet 192.168.1!
# Node 192.168.1.19 removed from subnet 192.168.1!
# Node 192.168.1.128 removed from subnet 192.168.1!
# Node 192.168.1.132 removed from subnet 192.168.1!
# Node 192.168.1.52 removed from subnet 192.168.1!
# Node 192.168.1.22 removed from subnet 192.168.1!
# Node 192.168.1.13 removed from subnet 192.168.1!
# Node 192.168.1.70 removed from subnet 192.168.1!
# Node 192.168.1.119 removed from subnet 192.168.1!
# Node 192.168.1.165 removed from subnet 192.168.1!
# Node 192.168.1.48 removed from subnet 192.168.1!
# Node 192.168.1.235 removed from subnet 192.168.1!
# Node 192.168.1.189 removed from subnet 192.168.1!
# Node 192.168.1.3 removed from subnet 192.168.1!
# Node 192.168.1.73 removed from subnet 192.168.1!
# Node 192.168.1.203 removed from subnet 192.168.1!
# Node 192.168.1.248 removed from subnet 192.168.1!
# Node 192.168.1.171 removed from subnet 192.168.1!
# Node 192.168.1.94 removed from subnet 192.168.1!
# Node 192.168.1.83 removed from subnet 192.168.1!
# Node 192.168.1.34 removed from subnet 192.168.1!
# Node 192.168.1.28 removed from subnet 192.168.1!
# Node 192.168.1.195 removed from subnet 192.168.1!
# Node 192.168.1.206 removed from subnet 192.168.1!
# Node 192.168.1.41 removed from subnet 192.168.1!
# Node 192.168.1.79 removed from subnet 192.168.1!
# Node 192.168.1.95 removed from subnet 192.168.1!
# Node 192.168.1.33 removed from subnet 192.168.1!
# Node 192.168.1.218 removed from subnet 192.168.1!
# Node 192.168.1.38 removed from subnet 192.168.1!
# Node 192.168.1.137 removed from subnet 192.168.1!
# Node 192.168.1.230 removed from subnet 192.168.1!
# Node 192.168.1.133 removed from subnet 192.168.1!
# Node 192.168.1.109 removed from subnet 192.168.1!
# Node 192.168.1.76 removed from subnet 192.168.1!
# Node 192.168.1.153 removed from subnet 192.168.1!
# Node 192.168.1.104 removed from subnet 192.168.1!
# Node 192.168.1.18 removed from subnet 192.168.1!
# Node 192.168.1.31 removed from subnet 192.168.1!
# Node 192.168.1.47 removed from subnet 192.168.1!
# Node 192.168.1.181 removed from subnet 192.168.1!
# Node 192.168.1.188 removed from subnet 192.168.1!
# Node 192.168.1.185 removed from subnet 192.168.1!
# Node 192.168.1.254 removed from subnet 192.168.1!
# Node 192.168.1.251 removed from subnet 192.168.1!
# Node 192.168.1.183 removed from subnet 192.168.1!
# Node 192.168.1.110 removed from subnet 192.168.1!
# Node 192.168.1.186 removed from subnet 192.168.1!
# Node 192.168.1.227 removed from subnet 192.168.1!
# Node 192.168.1.219 removed from subnet 192.168.1!
# Node 192.168.1.199 removed from subnet 192.168.1!
# Node 192.168.1.107 removed from subnet 192.168.1!
# Node 192.168.5.121 removed from subnet 192.168.5!
# Node 192.168.5.137 removed from subnet 192.168.5!
# Node 192.168.5.0 removed from subnet 192.168.5!
# Node 192.168.5.217 removed from subnet 192.168.5!
# Node 192.168.5.62 removed from subnet 192.168.5!
# Node 192.168.5.202 removed from subnet 192.168.5!
# Node 192.168.5.80 removed from subnet 192.168.5!
# Node 192.168.5.16 removed from subnet 192.168.5!
# Node 192.168.5.14 removed from subnet 192.168.5!
# Node 192.168.5.133 removed from subnet 192.168.5!
# Node 192.168.5.196 removed from subnet 192.168.5!
# Node 192.168.5.63 removed from subnet 192.168.5!
# Node 192.168.5.203 removed from subnet 192.168.5!
# Node 192.168.5.17 removed from subnet 192.168.5!
# Node 192.168.5.209 removed from subnet 192.168.5!
# Node 192.168.5.41 removed from subnet 192.168.5!
# Node 192.168.5.211 removed from subnet 192.168.5!
# Node 192.168.5.77 removed from subnet 192.168.5!
# Node 192.168.5.223 removed from subnet 192.168.5!
# Node 192.168.5.231 removed from subnet 192.168.5!
# Node 192.168.5.94 removed from subnet 192.168.5!
# Node 192.168.5.113 removed from subnet 192.168.5!
# Node 192.168.5.206 removed from subnet 192.168.5!
# Node 192.168.5.38 removed from subnet 192.168.5!
# Node 192.168.5.169 removed from subnet 192.168.5!
# Node 192.168.5.192 removed from subnet 192.168.5!
# Node 192.168.5.191 removed from subnet 192.168.5!
# Node 192.168.5.68 removed from subnet 192.168.5!
# Node 192.168.5.4 removed from subnet 192.168.5!
# Node 192.168.5.219 removed from subnet 192.168.5!
# Node 192.168.5.67 removed from subnet 192.168.5!
# Node 192.168.5.199 removed from subnet 192.168.5!
# Node 192.168.5.204 removed from subnet 192.168.5!
# Node 192.168.5.252 removed from subnet 192.168.5!
# Node 192.168.5.131 removed from subnet 192.168.5!
# Node 192.168.5.93 removed from subnet 192.168.5!
# Node 192.168.5.201 removed from subnet 192.168.5!
# Node 192.168.5.22 removed from subnet 192.168.5!
# Node 192.168.5.116 removed from subnet 192.168.5!
# Node 192.168.5.163 removed from subnet 192.168.5!
# Node 192.168.5.210 removed from subnet 192.168.5!
# Node 192.168.5.251 removed from subnet 192.168.5!
# Node 192.168.5.27 removed from subnet 192.168.5!
# Node 192.168.5.84 removed from subnet 192.168.5!
# Node 192.168.5.15 removed from subnet 192.168.5!
# Node 192.168.5.221 removed from subnet 192.168.5!
# Node 192.168.5.81 removed from subnet 192.168.5!
# Node 192.168.5.145 removed from subnet 192.168.5!
# Node 192.168.5.216 removed from subnet 192.168.5!
# Node 192.168.5.143 removed from subnet 192.168.5!
# Node 192.168.5.188 removed from subnet 192.168.5!
# Node 192.168.5.144 removed from subnet 192.168.5!
# Node 192.168.5.7 removed from subnet 192.168.5!
# Node 192.168.5.177 removed from subnet 192.168.5!
# Node 192.168.5.72 removed from subnet 192.168.5!
# Node 192.168.5.134 removed from subnet 192.168.5!
# Node 192.168.5.232 removed from subnet 192.168.5!
# Node 192.168.5.2 removed from subnet 192.168.5!
# Node 192.168.5.31 removed from subnet 192.168.5!
# Node 192.168.5.160 removed from subnet 192.168.5!
# Node 192.168.5.70 removed from subnet 192.168.5!
# Node 192.168.5.180 removed from subnet 192.168.5!
# Node 192.168.5.88 removed from subnet 192.168.5!
# Node 192.168.5.43 removed from subnet 192.168.5!
# Node 192.168.5.153 removed from subnet 192.168.5!
# Node 192.168.5.194 removed from subnet 192.168.5!
# Node 192.168.5.92 removed from subnet 192.168.5!
# Node 192.168.5.74 removed from subnet 192.168.5!
# Node 192.168.5.56 removed from subnet 192.168.5!
# Node 192.168.5.127 removed from subnet 192.168.5!
# Node 192.168.5.170 removed from subnet 192.168.5!
# Node 192.168.5.237 removed from subnet 192.168.5!
# Node 192.168.5.36 removed from subnet 192.168.5!
# Node 192.168.5.132 removed from subnet 192.168.5!
# Node 192.168.5.98 removed from subnet 192.168.5!
# Node 192.168.5.51 removed from subnet 192.168.5!
# Node 192.168.5.179 removed from subnet 192.168.5!
# Node 192.168.5.105 removed from subnet 192.168.5!
# Node 192.168.5.181 removed from subnet 192.168.5!
# Node 192.168.5.136 removed from subnet 192.168.5!
# Node 192.168.5.66 removed from subnet 192.168.5!
# Node 192.168.5.102 removed from subnet 192.168.5!
# Node 192.168.5.47 removed from subnet 192.168.5!
# Node 192.168.5.126 removed from subnet 192.168.5!
# Node 192.168.5.83 removed from subnet 192.168.5!
# Node 192.168.5.165 removed from subnet 192.168.5!
# Node 192.168.5.123 removed from subnet 192.168.5!
# Node 192.168.5.205 removed from subnet 192.168.5!
# Node 192.168.5.234 removed from subnet 192.168.5!
# Node 192.168.5.91 removed from subnet 192.168.5!
# Node 192.168.5.227 removed from subnet 192.168.5!
# Node 192.168.5.19 removed from subnet 192.168.5!
# Node 192.168.5.82 removed from subnet 192.168.5!
# Node 192.168.5.147 removed from subnet 192.168.5!
# Node 192.168.5.49 removed from subnet 192.168.5!
# Node 192.168.5.171 removed from subnet 192.168.5!
# Node 192.168.5.45 removed from subnet 192.168.5!
# Node 192.168.5.135 removed from subnet 192.168.5!
# Node 192.168.5.99 removed from subnet 192.168.5!
# Node 192.168.5.52 removed from subnet 192.168.5!
# Node 192.168.5.146 removed from subnet 192.168.5!
# Node 192.168.5.96 removed from subnet 192.168.5!
# Node 192.168.5.86 removed from subnet 192.168.5!
# Node 192.168.5.241 removed from subnet 192.168.5!
# Node 192.168.5.64 removed from subnet 192.168.5!
# Node 192.168.5.30 removed from subnet 192.168.5!
# Node 192.168.5.11 removed from subnet 192.168.5!
# Node 192.168.5.159 removed from subnet 192.168.5!
# Node 192.168.5.78 removed from subnet 192.168.5!
# Node 192.168.5.208 removed from subnet 192.168.5!
# Node 192.168.5.222 removed from subnet 192.168.5!
# Node 192.168.5.60 removed from subnet 192.168.5!
# Node 192.168.5.40 removed from subnet 192.168.5!
# Node 192.168.5.151 removed from subnet 192.168.5!
# Node 192.168.5.212 removed from subnet 192.168.5!
# Node 192.168.5.50 removed from subnet 192.168.5!
# Node 192.168.5.229 removed from subnet 192.168.5!
# Node 192.168.5.33 removed from subnet 192.168.5!
# Node 192.168.5.128 removed from subnet 192.168.5!
# Node 192.168.5.141 removed from subnet 192.168.5!
# Node 192.168.5.166 removed from subnet 192.168.5!
# Node 192.168.5.124 removed from subnet 192.168.5!
# Node 192.168.5.95 removed from subnet 192.168.5!
# Node 192.168.5.32 removed from subnet 192.168.5!
# Node 192.168.5.61 removed from subnet 192.168.5!
# Node 192.168.5.238 removed from subnet 192.168.5!
# Node 192.168.5.235 removed from subnet 192.168.5!
# Node 192.168.5.115 removed from subnet 192.168.5!
# Node 192.168.5.35 removed from subnet 192.168.5!
# Node 192.168.5.112 removed from subnet 192.168.5!
# Node 192.168.5.3 removed from subnet 192.168.5!
# Node 192.168.5.214 removed from subnet 192.168.5!
# Node 192.168.5.107 removed from subnet 192.168.5!
# Node 192.168.5.90 removed from subnet 192.168.5!
# Node 192.168.5.71 removed from subnet 192.168.5!
# Node 192.168.5.26 removed from subnet 192.168.5!
# Node 192.168.5.73 removed from subnet 192.168.5!
# Node 192.168.5.240 removed from subnet 192.168.5!
# Node 192.168.5.140 removed from subnet 192.168.5!
# Node 192.168.5.185 removed from subnet 192.168.5!
# Node 192.168.5.173 removed from subnet 192.168.5!
# Node 192.168.5.117 removed from subnet 192.168.5!
# Node 192.168.5.69 removed from subnet 192.168.5!
# Node 192.168.5.198 removed from subnet 192.168.5!
# Node 192.168.5.176 removed from subnet 192.168.5!
# Node 192.168.5.119 removed from subnet 192.168.5!
# Node 192.168.5.246 removed from subnet 192.168.5!
# Node 192.168.5.148 removed from subnet 192.168.5!
# Node 192.168.5.85 removed from subnet 192.168.5!
# Node 192.168.5.54 removed from subnet 192.168.5!
# Node 192.168.5.10 removed from subnet 192.168.5!
# Node 192.168.5.48 removed from subnet 192.168.5!
# Node 192.168.5.34 removed from subnet 192.168.5!
# Node 192.168.5.55 removed from subnet 192.168.5!
# Node 192.168.5.254 removed from subnet 192.168.5!
# Node 192.168.5.161 removed from subnet 192.168.5!
# Node 192.168.5.244 removed from subnet 192.168.5!
# Node 192.168.5.178 removed from subnet 192.168.5!
# Node 192.168.5.242 removed from subnet 192.168.5!
# Node 192.168.5.186 removed from subnet 192.168.5!
# Node 192.168.5.130 removed from subnet 192.168.5!
# Node 192.168.5.189 removed from subnet 192.168.5!
# Node 192.168.5.218 removed from subnet 192.168.5!
# Node 192.168.5.195 removed from subnet 192.168.5!
# Node 192.168.5.245 removed from subnet 192.168.5!
# Node 192.168.5.101 removed from subnet 192.168.5!
# Node 192.168.5.21 removed from subnet 192.168.5!
# Node 192.168.5.253 removed from subnet 192.168.5!
# Node 192.168.5.18 removed from subnet 192.168.5!
# Node 192.168.5.120 removed from subnet 192.168.5!
# Node 192.168.5.44 removed from subnet 192.168.5!
# Node 192.168.5.5 removed from subnet 192.168.5!
# Node 192.168.5.154 removed from subnet 192.168.5!
# Node 192.168.5.228 removed from subnet 192.168.5!
# Node 192.168.5.58 removed from subnet 192.168.5!
# Node 192.168.5.53 removed from subnet 192.168.5!
# Node 192.168.5.139 removed from subnet 192.168.5!
# Node 192.168.5.42 removed from subnet 192.168.5!
# Node 192.168.5.89 removed from subnet 192.168.5!
# Node 192.168.5.129 removed from subnet 192.168.5!
# Node 192.168.5.29 removed from subnet 192.168.5!
# Node 192.168.5.150 removed from subnet 192.168.5!
# Node 192.168.5.164 removed from subnet 192.168.5!
# Node 192.168.5.193 removed from subnet 192.168.5!
# Node 192.168.5.110 removed from subnet 192.168.5!
# Node 192.168.5.109 removed from subnet 192.168.5!
# Node 192.168.5.24 removed from subnet 192.168.5!
# Node 192.168.5.76 removed from subnet 192.168.5!
# Node 192.168.5.79 removed from subnet 192.168.5!
# Node 192.168.5.225 removed from subnet 192.168.5!
# Node 192.168.5.250 removed from subnet 192.168.5!
# Node 192.168.5.162 removed from subnet 192.168.5!
# Node 192.168.5.142 removed from subnet 192.168.5!
# Node 192.168.10.81 removed from subnet 192.168.10!
# Node 192.168.10.0 removed from subnet 192.168.10!
# Node 192.168.10.195 removed from subnet 192.168.10!
# Node 192.168.10.83 removed from subnet 192.168.10!
# Node 192.168.10.164 removed from subnet 192.168.10!
# Node 192.168.10.18 removed from subnet 192.168.10!
# Node 192.168.10.13 removed from subnet 192.168.10!
# Node 192.168.10.38 removed from subnet 192.168.10!
# Node 192.168.10.158 removed from subnet 192.168.10!
# Node 192.168.10.199 removed from subnet 192.168.10!
# Node 192.168.10.229 removed from subnet 192.168.10!
# Node 192.168.10.36 removed from subnet 192.168.10!
# Node 192.168.10.175 removed from subnet 192.168.10!
# Node 192.168.10.191 removed from subnet 192.168.10!
# Node 192.168.10.223 removed from subnet 192.168.10!
# Node 192.168.10.73 removed from subnet 192.168.10!
# Node 192.168.10.75 removed from subnet 192.168.10!
# Node 192.168.10.33 removed from subnet 192.168.10!
# Node 192.168.10.197 removed from subnet 192.168.10!
# Node 192.168.10.31 removed from subnet 192.168.10!
# Node 192.168.10.54 removed from subnet 192.168.10!
# Node 192.168.10.181 removed from subnet 192.168.10!
# Node 192.168.10.119 removed from subnet 192.168.10!
# Node 192.168.10.89 removed from subnet 192.168.10!
# Node 192.168.10.27 removed from subnet 192.168.10!
# Node 192.168.10.211 removed from subnet 192.168.10!
# Node 192.168.10.100 removed from subnet 192.168.10!
# Node 192.168.10.69 removed from subnet 192.168.10!
# Node 192.168.10.60 removed from subnet 192.168.10!
# Node 192.168.10.196 removed from subnet 192.168.10!
# Node 192.168.10.80 removed from subnet 192.168.10!
# Node 192.168.10.210 removed from subnet 192.168.10!
# Node 192.168.10.161 removed from subnet 192.168.10!
# Node 192.168.10.231 removed from subnet 192.168.10!
# Node 192.168.10.132 removed from subnet 192.168.10!
# Node 192.168.10.188 removed from subnet 192.168.10!
# Node 192.168.10.176 removed from subnet 192.168.10!
# Node 192.168.10.78 removed from subnet 192.168.10!
# Node 192.168.10.22 removed from subnet 192.168.10!
# Node 192.168.10.32 removed from subnet 192.168.10!
# Node 192.168.10.30 removed from subnet 192.168.10!
# Node 192.168.10.153 removed from subnet 192.168.10!
# Node 192.168.10.144 removed from subnet 192.168.10!
# Node 192.168.10.232 removed from subnet 192.168.10!
# Node 192.168.10.233 removed from subnet 192.168.10!
# Node 192.168.10.246 removed from subnet 192.168.10!
# Node 192.168.10.122 removed from subnet 192.168.10!
# Node 192.168.10.254 removed from subnet 192.168.10!
# Node 192.168.10.216 removed from subnet 192.168.10!
# Node 192.168.10.35 removed from subnet 192.168.10!
# Node 192.168.10.92 removed from subnet 192.168.10!
# Node 192.168.10.245 removed from subnet 192.168.10!
# Node 192.168.10.234 removed from subnet 192.168.10!
# Node 192.168.10.242 removed from subnet 192.168.10!
# Node 192.168.10.95 removed from subnet 192.168.10!
# Node 192.168.10.1 removed from subnet 192.168.10!
# Node 192.168.10.230 removed from subnet 192.168.10!
# Node 192.168.10.137 removed from subnet 192.168.10!
# Node 192.168.10.207 removed from subnet 192.168.10!
# Node 192.168.10.19 removed from subnet 192.168.10!
# Node 192.168.10.8 removed from subnet 192.168.10!
# Node 192.168.10.141 removed from subnet 192.168.10!
# Node 192.168.10.115 removed from subnet 192.168.10!
# Node 192.168.10.155 removed from subnet 192.168.10!
# Node 192.168.10.160 removed from subnet 192.168.10!
# Node 192.168.10.77 removed from subnet 192.168.10!
# Node 192.168.10.129 removed from subnet 192.168.10!
# Node 192.168.10.202 removed from subnet 192.168.10!
# Node 192.168.10.157 removed from subnet 192.168.10!
# Node 192.168.10.193 removed from subnet 192.168.10!
# Node 192.168.10.219 removed from subnet 192.168.10!
# Node 192.168.10.23 removed from subnet 192.168.10!
# Node 192.168.10.50 removed from subnet 192.168.10!
# Node 192.168.10.172 removed from subnet 192.168.10!
# Node 192.168.10.88 removed from subnet 192.168.10!
# Node 192.168.10.149 removed from subnet 192.168.10!
# Node 192.168.10.140 removed from subnet 192.168.10!
# Node 192.168.10.134 removed from subnet 192.168.10!
# Node 192.168.10.228 removed from subnet 192.168.10!
# Node 192.168.10.237 removed from subnet 192.168.10!
# Node 192.168.10.146 removed from subnet 192.168.10!
# Node 192.168.10.135 removed from subnet 192.168.10!
# Node 192.168.10.222 removed from subnet 192.168.10!
# Node 192.168.10.82 removed from subnet 192.168.10!
# Node 192.168.10.142 removed from subnet 192.168.10!
# Node 192.168.10.85 removed from subnet 192.168.10!
# Node 192.168.10.184 removed from subnet 192.168.10!
# Node 192.168.10.94 removed from subnet 192.168.10!
# Node 192.168.10.251 removed from subnet 192.168.10!
# Node 192.168.10.179 removed from subnet 192.168.10!
# Node 192.168.10.43 removed from subnet 192.168.10!
# Node 192.168.10.11 removed from subnet 192.168.10!
# Node 192.168.10.217 removed from subnet 192.168.10!
# Node 192.168.10.154 removed from subnet 192.168.10!
# Node 192.168.10.112 removed from subnet 192.168.10!
# Node 192.168.10.3 removed from subnet 192.168.10!
# Node 192.168.10.56 removed from subnet 192.168.10!
# Node 192.168.10.72 removed from subnet 192.168.10!
# Node 192.168.10.84 removed from subnet 192.168.10!
# Node 192.168.10.117 removed from subnet 192.168.10!
# Node 192.168.10.5 removed from subnet 192.168.10!
# Node 192.168.10.166 removed from subnet 192.168.10!
# Node 192.168.10.213 removed from subnet 192.168.10!
# Node 192.168.10.249 removed from subnet 192.168.10!
# Node 192.168.10.180 removed from subnet 192.168.10!
# Node 192.168.10.53 removed from subnet 192.168.10!
# Node 192.168.10.46 removed from subnet 192.168.10!
# Node 192.168.10.125 removed from subnet 192.168.10!
# Node 192.168.10.189 removed from subnet 192.168.10!
# Node 192.168.10.236 removed from subnet 192.168.10!
# Node 192.168.10.215 removed from subnet 192.168.10!
# Node 192.168.10.6 removed from subnet 192.168.10!
# Node 192.168.10.67 removed from subnet 192.168.10!
# Node 192.168.10.9 removed from subnet 192.168.10!
# Node 192.168.10.45 removed from subnet 192.168.10!
# Node 192.168.10.147 removed from subnet 192.168.10!
# Node 192.168.10.150 removed from subnet 192.168.10!
# Node 192.168.10.168 removed from subnet 192.168.10!
# Node 192.168.10.136 removed from subnet 192.168.10!
# Node 192.168.10.208 removed from subnet 192.168.10!
# Node 192.168.10.169 removed from subnet 192.168.10!
# Node 192.168.10.143 removed from subnet 192.168.10!
# Node 192.168.10.98 removed from subnet 192.168.10!
# Node 192.168.10.93 removed from subnet 192.168.10!
# Node 192.168.10.86 removed from subnet 192.168.10!
# Node 192.168.10.47 removed from subnet 192.168.10!
# Node 192.168.10.159 removed from subnet 192.168.10!
# Node 192.168.10.114 removed from subnet 192.168.10!
# Node 192.168.10.87 removed from subnet 192.168.10!
# Node 192.168.10.205 removed from subnet 192.168.10!
# Node 192.168.10.15 removed from subnet 192.168.10!
# Node 192.168.10.244 removed from subnet 192.168.10!
# Node 192.168.10.49 removed from subnet 192.168.10!
# Node 192.168.10.37 removed from subnet 192.168.10!
# Node 192.168.10.29 removed from subnet 192.168.10!
# Node 192.168.10.124 removed from subnet 192.168.10!
# Node 192.168.10.105 removed from subnet 192.168.10!
# Node 192.168.10.20 removed from subnet 192.168.10!
# Node 192.168.10.128 removed from subnet 192.168.10!
# Node 192.168.10.55 removed from subnet 192.168.10!
# Node 192.168.10.225 removed from subnet 192.168.10!
# Node 192.168.10.145 removed from subnet 192.168.10!
# Node 192.168.10.64 removed from subnet 192.168.10!
# Node 192.168.10.42 removed from subnet 192.168.10!
# Node 192.168.10.62 removed from subnet 192.168.10!
# Node 192.168.10.103 removed from subnet 192.168.10!
# Node 192.168.10.148 removed from subnet 192.168.10!
# Node 192.168.10.162 removed from subnet 192.168.10!
# Node 192.168.10.40 removed from subnet 192.168.10!
# Node 192.168.10.186 removed from subnet 192.168.10!
# Node 192.168.10.107 removed from subnet 192.168.10!
# Node 192.168.10.178 removed from subnet 192.168.10!
# Node 192.168.10.44 removed from subnet 192.168.10!
# Node 192.168.10.226 removed from subnet 192.168.10!
# Node 192.168.10.104 removed from subnet 192.168.10!
# Node 192.168.10.243 removed from subnet 192.168.10!
# Node 192.168.10.68 removed from subnet 192.168.10!
# Node 192.168.10.74 removed from subnet 192.168.10!
# Node 192.168.10.250 removed from subnet 192.168.10!
# Node 192.168.10.187 removed from subnet 192.168.10!
# Node 192.168.10.97 removed from subnet 192.168.10!
# Node 192.168.10.109 removed from subnet 192.168.10!
# Node 192.168.10.131 removed from subnet 192.168.10!
# Node 192.168.10.126 removed from subnet 192.168.10!
# Node 192.168.10.48 removed from subnet 192.168.10!
# Node 192.168.10.198 removed from subnet 192.168.10!
# Node 192.168.10.16 removed from subnet 192.168.10!
# Node 192.168.10.41 removed from subnet 192.168.10!
# Node 192.168.10.253 removed from subnet 192.168.10!
# Node 192.168.10.212 removed from subnet 192.168.10!
# Node 192.168.10.66 removed from subnet 192.168.10!
# Node 192.168.10.190 removed from subnet 192.168.10!
# Node 192.168.10.248 removed from subnet 192.168.10!
# Node 192.168.10.121 removed from subnet 192.168.10!
# Node 192.168.10.24 removed from subnet 192.168.10!
# Node 192.168.10.91 removed from subnet 192.168.10!
# Node 192.168.10.63 removed from subnet 192.168.10!
# Node 192.168.10.52 removed from subnet 192.168.10!
# Node 192.168.10.7 removed from subnet 192.168.10!
# Node 192.168.10.167 removed from subnet 192.168.10!
# Node 192.168.10.58 removed from subnet 192.168.10!
# Node 192.168.10.221 removed from subnet 192.168.10!
# Node 192.168.10.12 removed from subnet 192.168.10!
# Node 192.168.10.183 removed from subnet 192.168.10!
# Node 192.168.10.138 removed from subnet 192.168.10!
# Node 192.168.10.111 removed from subnet 192.168.10!
# Node 192.168.10.201 removed from subnet 192.168.10!
# Node 192.168.10.96 removed from subnet 192.168.10!
# Node 192.168.10.21 removed from subnet 192.168.10!
# Node 192.168.10.14 removed from subnet 192.168.10!
# Node 192.168.10.174 removed from subnet 192.168.10!
# Node 192.168.10.240 removed from subnet 192.168.10!
# Node 192.168.10.34 removed from subnet 192.168.10!
# Node 192.168.10.156 removed from subnet 192.168.10!
# Node 192.168.10.252 removed from subnet 192.168.10!
# Node 192.168.10.139 removed from subnet 192.168.10!
# Node 192.168.10.71 removed from subnet 192.168.10!
# Node 192.168.10.200 removed from subnet 192.168.10!
# Node 192.168.10.130 removed from subnet 192.168.10!
# Node 192.168.10.4 removed from subnet 192.168.10!
# Node 192.168.10.123 removed from subnet 192.168.10!
# Node 192.168.10.10 removed from subnet 192.168.10!
# Node 192.168.10.61 removed from subnet 192.168.10!
# Node 192.168.10.151 removed from subnet 192.168.10!
# Node 192.168.10.185 removed from subnet 192.168.10!
# Node 192.168.10.59 removed from subnet 192.168.10!
# Node 192.168.10.194 removed from subnet 192.168.10!
# Node 192.168.10.39 removed from subnet 192.168.10!
# Node 192.168.10.192 removed from subnet 192.168.10!
# Node 192.168.10.224 removed from subnet 192.168.10!
# Node 192.168.10.116 removed from subnet 192.168.10!
# Node 192.168.10.220 removed from subnet 192.168.10!
# Node 192.168.10.203 removed from subnet 192.168.10!
# Node 192.168.10.90 removed from subnet 192.168.10!
# Node 192.168.10.177 removed from subnet 192.168.10!
# Node 192.168.10.218 removed from subnet 192.168.10!
# Node 192.168.10.165 removed from subnet 192.168.10!
# Node 192.168.10.65 removed from subnet 192.168.10!
# Node 192.168.10.108 removed from subnet 192.168.10!
# Node 192.168.10.182 removed from subnet 192.168.10!
# Node 192.168.10.118 removed from subnet 192.168.10!
# Node 192.168.10.106 removed from subnet 192.168.10!
# Node 192.168.10.57 removed from subnet 192.168.10!
# Node 192.168.10.204 removed from subnet 192.168.10!
# Node 192.168.10.25 removed from subnet 192.168.10!
# Node 192.168.10.26 removed from subnet 192.168.10!
